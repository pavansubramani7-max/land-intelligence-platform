# %% [markdown]
# # Valuation Model Training

# %%
import sys
sys.path.insert(0, '../../backend')
from app.ml.train_valuation import train_valuation_models
metrics = train_valuation_models('../data/sample_land_data.csv')
print(metrics)

# %%
import pandas as pd
import matplotlib.pyplot as plt
results = pd.DataFrame(metrics).T
results[['mae', 'rmse', 'r2']].plot(kind='bar', figsize=(10, 5))
plt.title('Model Comparison')
plt.xticks(rotation=0)
plt.show()
