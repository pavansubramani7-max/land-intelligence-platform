# %% [markdown]
# # Fraud Detection Model

# %%
import sys
sys.path.insert(0, '../../backend')
from app.ml.train_fraud import train_fraud_models
results = train_fraud_models('../data/sample_land_data.csv')
print(results)
