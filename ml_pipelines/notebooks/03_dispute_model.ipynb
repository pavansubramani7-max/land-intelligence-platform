# %% [markdown]
# # Dispute Risk Model

# %%
import sys
sys.path.insert(0, '../../backend')
from app.ml.train_dispute import train_dispute_models
results = train_dispute_models('../data/sample_land_data.csv')
print(results)
